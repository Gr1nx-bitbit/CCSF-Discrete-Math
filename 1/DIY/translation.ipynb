# %% [markdown]
# # 1 Translate each of these arguments into formal logic by using symbols to stand in for the constituent propositions and connectives.
# **a. Using p=”there’s lots of water on the ground,” q=”there’s a chance of more rain today,” r=”I should bring my umbrella.”**
#
# |Original Sentence|Simplified Sentence|Propositional Logic Form|
# |-----------------|-------------------|------------------------|
# |In general, I know that if there’s lots of water on the ground, there’s a chance of more rain today.|If there’s lots of water on the ground, there’s a chance of more rain today.|p -> q|
# |There is lots of water on the ground.|There is lots of water on the ground.|p|
# |So there’s a chance of more rain today.|There’s a chance of more rain today.|q|
# |And if there’s a chance of more rain today, I should bring my umbrella.|If there’s a chance of more rain today, I should bring my umbrella.|q -> r|
# |So I guess I should bring my umbrella.|I should bring my umbrella.|r|
#
# **b. Using p=”it makes a buzzing noise,” q=”it’s a bee”, r=”it makes honey,” z=”I can eat it”: (For this, translate “the only reason for x is y” as “x→y”)**
#
# |Original Sentence|Simplified Sentence|Propositional Logic Form|
# |-----------------|-------------------|------------------------|
# |That buzzing noise means something.|It makes a buzzing noise.|p|
# |Now, the only reason for making a buzzing noise that I know of is because you are…a bee!|If it makes a buzzing noise, it’s a bee.|p -> q|
# |And the only reason for being a bee is to make honey.|If you're a bee, then you make honey|q -> r|
# |And the only reason for making honey is so I can eat it.|If honey is made, then I can eat it|r -> z|
#
# **c. Translate each of these reasoning processes using appropriate letters and symbols to show the similarities in the reasoning processes.**
#
# i. Using f(x)=x2-3x-4, a=4.
#
# |Original Sentence|Simplified Sentence|Propositional Logic Form|
# |-----------------|-------------------|------------------------|
# |In general, if a polynomial f has x-a as a factor, then f(a)=0.|If [f has x-a as a factor]-(p), then [f(a)=0]-(q).|p -> q|
# |In this case, f(a)=0.|f(a)=0.|q|
# |So f must have x-a as a factor.|f has x-a as a factor.|p|
#
# ii.
#
# |Original Sentence|Simplified Sentence|Propositional Logic Form|
# |-----------------|-------------------|------------------------|
# |If Biden cheated in 2020, he would get much more votes than previous Democratic candidates.|If Biden cheated (p), he has more votes (q)|p -> q|
# |He did get much more votes than previous Democratic candidates.|he has more votes|q|
# |Therefore, Biden cheated in 2020.|Biden cheated|p|
# S = ((p -> q) ^ q) -> p
#
# iii.
#
# |Original Sentence|Simplified Sentence|Propositional Logic Form|
# |-----------------|-------------------|------------------------|
# |If an animal is a dog, then it has four legs.|If it’s a dog (p), then it has four legs (q).|p -> q|
# |My cat has four legs.|It has four legs.|q|
# |Therefore, my cat is a dog.|It's a dog.|p|
# S = ((p -> q) ^ q) -> p
#
# # 2
#
# Problem: In 1b, Pooh doesn’t explicitly state his conclusions, but he is drawing conclusions. What are they? Rewrite your formal-logic translation to show the implied conclusions. (For example, when Pooh says, “Now, the only reason for making a buzzing noise that I know of is because you are…a bee!”, we can translate this as “if it makes a buzzing noise, it’s a bee” but he’s concluding “therefore, it’s a bee.”)
#
# Pooh is drawing conclusions whenever he *implies* something such as when he says, if it buzzes, then it's a bee. Another conclusion would be that, if it's a bee, then it makes honey, and the last inferred conclusion is when Pooh says that "if it's honey, I can eat it."
#
# # 3
#
# Problem: In 1c, all three examples are using the same inference rule—i.e., they’re all drawing the same kind of conclusion on the basis of the same kind of known statements.
#
# a. In which cases is the conclusion true? Explain.
#     - The case is true in 1.c.i since we can mathmatically show that f(a) = 0. There are no other valid cases
#
# b. In which cases are the starting known statements true?
#     - 1.c.i is true since we know f(a) = 0 is true
#     - 1.c.ii is probably true (I don't know how many votes he had compared to previous democratic candidates).
#     - 1.c.iii is not Always true (some dogs might not have 4 legs)
#
# c. An inference rule is valid if it always produces true conclusions (if the statements leading up to the conclusions are true). For example, the inference rule used in 1a that if we know p, and we know p->q, then q must be true is valid. Explain why example iii proves that the inference rule used in 1c is not valid.
#     - just because p implies q, does not always mean that q is true if p is true e.g. a dog can have three legs but is still a dog, in that sence p does not imply q yet p -> q still produces a true result. In the same sense, an animal can have 4 legs and not be a dog such as cat, in this sense p -> q produces a false result since even though the animal has four legs (p) it is not a dog (q) but instead a cat.
#
# d. Why do we care if the inference rule is valid? What does the invalidity of the inference rule mean about 1c examples i and ii?
#     - Because even if something seems logical, it might really be false such as 1.c.i and 1.c.ii
